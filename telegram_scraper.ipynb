# %%
import pandas as pd
import os
import time
import configparser
import calendar
from telethon.sync import TelegramClient
from telethon.tl.functions.messages import GetHistoryRequest
import json
import time
from datetime import datetime, timedelta
import asyncio

# %%
get_date_interval_from_filename("telegram_channels_june_2022.csv")
# Out:
# (datetime.date(2022, 1, 1), datetime.date(2022, 6, 30))

# %%
def get_date_interval_from_filename(filename):
    # Extract the date from the filename
    month_year = filename.split('_')[-2:]  # Extract the month and year
    month_name = month_year[0]
    year = int(month_year[1].split('.')[0])

    # Convert month from name to number
    month = datetime.strptime(month_name, '%B').month

    # Create the start date as the first day of the six months before
    if month == 6:
        start_date = datetime(year, 1, 1)
    else:
        start_date = datetime(year, 7, 1)

    # Create the end date as the last day of the month before the one specified in filename
    if month == 1:
        end_date = datetime(year-1, 12, 31)
    else:
        end_date = datetime(year, 6, 30)

    return start_date.date(), end_date.date()


def extract_top_channels(filename, top_n=20):
    df = pd.read_csv(filename)
    top_channels = df.nsmallest(top_n, 'rank')['channel_id']
    return top_channels


def extract_channel_info(filename):
    df = pd.read_csv(filename)
    return df

def get_date_interval_from_csv(row):
    # Convert start_date and end_date to integers before using them
    start_date = int(row['start_date'])
    end_date = int(row['end_date'])

    # Extract the start_date and end_date from the row of the CSV file
    start_date = datetime(start_date, 1, 1)
    end_date = datetime(end_date, 12, 31)
    return start_date.date(), end_date.date()


async def get_channel_messages(client, channel_id, start_date, end_date):
    channel = await client.get_entity(channel_id)

    limit = 100
    all_messages = []
    total_messages = 0
    total_count_limit = 0

    print(f"Fetching messages from {channel.title}")
    offset_id = 0
    break_flag = False
    while True:
        history = await client(GetHistoryRequest(
            peer=channel,
            limit=limit,
            offset_date=None,
            offset_id=offset_id,
            add_offset=0,
            max_id=0,
            min_id=0,
            hash=0
        ))
        if not history.messages:
            break
        messages = history.messages
        for message in messages:
            if message.date.date() < start_date:  # if message is older than start date
                break_flag = True
                break
            elif message.date.date() > end_date:  # if message is newer than end date
                continue
            all_messages.append(message.to_dict())
        if break_flag:
            break
        offset_id = messages[-1].id  # Get the id of the last message
        time.sleep(1)  # to prevent hitting rate limit
        total_messages = len(all_messages)
        print(f"\rFetched {total_messages} messages...", end='')
        if total_count_limit != 0 and total_messages >= total_count_limit:
            break
    print()  # Print a newline when done
    return all_messages


class DateTimeEncoder(json.JSONEncoder):
    def default(self, o):
        if isinstance(o, datetime):
            return o.isoformat()

        if isinstance(o, bytes):
            return list(o)

        return json.JSONEncoder.default(self, o)

def save_messages_to_json(channel_name, start_date, end_date, messages):
    filename = f"{channel_name}_{start_date}_{end_date}.json"
    with open(filename, 'w') as f:
        json.dump(messages, f, cls=DateTimeEncoder)
 
    
async def main(client, filename):
    start_time = time.time()
    channel_info = extract_channel_info(filename)
    for _, row in channel_info.iterrows():
        channel_id = row['channel_id']
        channel_link = row['channel_link']
        start_date, end_date = get_date_interval_from_csv(row)

        output_file = f"{channel_id}_{start_date}_{end_date}.json"
        if os.path.exists(output_file):
            print(f"Messages for {channel_id} have already been scraped. Skipping...")
            continue

        messages = await get_channel_messages(client, channel_link, start_date, end_date)
        save_messages_to_json(channel_id, start_date, end_date, messages)
    elapsed_time = time.time() - start_time
    print(f"\nTotal time elapsed: {elapsed_time:.2f} seconds")

# %%
# Reading Configs
config = configparser.ConfigParser()
config.read("config.ini")

# Setting configuration values
api_id = config['Telegram']['api_id']
api_hash = config['Telegram']['api_hash']

api_hash = str(api_hash)

phone = config['Telegram']['phone']
username = config['Telegram']['username']


client = TelegramClient(username, api_id, api_hash)
await client.start()
# Out:
# Please enter your phone (or bot token):  +447494238046
# Please enter the code you received:  57370
# Signed in successfully as Yana

# %%
if __name__ == "__main__":
    filename = "telegram_channels_with_dates.csv"
    await main(client, filename)
# Out:
# Messages for aavst55 have already been scraped. Skipping...
# Messages for Akashevarova have already been scraped. Skipping...
# Messages for Aksenov82 have already been scraped. Skipping...
# Messages for atc_atc have already been scraped. Skipping...
# Messages for babchenko77 have already been scraped. Skipping...
# Messages for bloodysx have already been scraped. Skipping...
# Messages for boilerroomchannel have already been scraped. Skipping...
# Messages for ctrs2018 have already been scraped. Skipping...
# Messages for Davydovln have already been scraped. Skipping...
# Messages for deputatdumy have already been scraped. Skipping...
# Messages for dmitrynikotin have already been scraped. Skipping...
# Messages for eschlmann have already been scraped. Skipping...
# Messages for gayasylum have already been scraped. Skipping...
# Messages for gayasylum have already been scraped. Skipping...
# Messages for generalsvr have already been scraped. Skipping...
# Messages for go338 have already been scraped. Skipping...
# Messages for golunovforever have already been scraped. Skipping...
# Messages for hellotransfer have already been scraped. Skipping...
# Messages for imnotbozhena have already been scraped. Skipping...
# Messages for itsorm have already been scraped. Skipping...
# Messages for kaktovottak have already been scraped. Skipping...
# Messages for karaulny have already been scraped. Skipping...
# Messages for kashinguru have already been scraped. Skipping...
# Messages for kbrvdvkr have already been scraped. Skipping...
# Messages for khodorkovski have already been scraped. Skipping...
# Messages for kompr have already been scraped. Skipping...
# Messages for kremlin_mother_expert have already been scraped. Skipping...
# Messages for kremlinprachka have already been scraped. Skipping...
# Messages for kstati_p have already been scraped. Skipping...
# Messages for leonid_volkov have already been scraped. Skipping...
# Messages for maester have already been scraped. Skipping...
# Fetching messages from Маргарита Симоньян
# Fetched 9516 messages...
# Fetching messages from Мария Захарова
# Fetched 5643 messages...
# Fetching messages from Медиатехнолог
# Fetched 15621 messages...
# Fetching messages from Дмитрий Медведев
# Fetched 345 messages...
# Fetching messages from Андрей Медведев
# Fetched 5383 messages...
# Fetching messages from Методичка
# Fetched 3686 messages...
# Fetching messages from Сергей Минаев
# Fetched 5591 messages...
# Fetching messages from Многонационал
# Fetched 2131 messages...
# Fetching messages from Мэр Москвы Сергей Собянин
# Fetched 3300 messages...
# Fetching messages from Комитет по Этике
# Fetched 154 messages...
# Fetching messages from Без комментариев
# Fetched 1920 messages...
# Fetching messages from Навальный
# Fetched 2861 messages...
# Fetching messages from НЕЧАЕВ
# Fetched 200 messages...
# Fetching messages from Протестная Россия
# Fetched 5526 messages...
# Fetching messages from НЕВЗОРОВ
# Fetched 4166 messages...
# Fetching messages from БЕСОГОН
# Fetched 200 messages...
# Fetching messages from Номенклатура
# Fetched 2690 messages...
# Fetching messages from Всевидящее око
# Fetched 745 messages...
# Fetching messages from АРМАГЕДДОНЫЧ
# Fetched 1389 messages...
# Fetching messages from АРМАГЕДДОНЫЧ
# Fetched 1808 messages...
# Fetching messages from Олег Царёв
# Fetched 2497 messages...
# Fetching messages from Дабл Ять
# Fetched 8153 messages...
# Fetching messages from Павел Чиков 🕊
# Fetched 1347 messages...
# Fetching messages from PLUSHEV/ПЛЮЩЕВ
# Fetched 5738 messages...
# Fetching messages from АДЕКВАТ Z
# Fetched 3038 messages...
# Fetching messages from Политбюро 2.0
# Fetched 2163 messages...
# Fetching messages from Политджойстик/Politjoystic
# Fetched 3672 messages...
# Fetching messages from Политджойстик/Politjoystic
# Fetched 5924 messages...
# Fetching messages from Темник
# Fetched 6132 messages...
# Fetching messages from ПОЛИТУПРАВА
# Fetched 640 messages...
# Fetching messages from Кепка Пригожина
# Fetched 1400 messages...
# Fetching messages from Пушилин Д.В.
# Fetched 500 messages...
# Fetching messages from Расстрига
# Fetched 7362 messages...
# Fetching messages from Пивоваров (Редакция)
# Fetched 20699 messages...
# Fetching messages from Kadyrov_95
# Fetched 3099 messages...
# Fetching messages from РОСПРЕСС
# Fetched 0 messages...
# Fetching messages from Ротонда
# Fetched 412 messages...
# Fetching messages from FTP Мобилизация
# Fetched 5944 messages...
# Fetching messages from Русская Пресса
# Fetched 138 messages...
# Fetching messages from НЕЗЫГАРЬ
# Fetched 32436 messages...
# Fetching messages from Усы Пескова
# Fetched 12300 messages...
# Fetching messages from КриптоСаня
# Fetched 502 messages...
# Fetching messages from Kotsnews
# Fetched 9986 messages...
# Fetching messages from Смирнов
# Fetched 1562 messages...
# Fetching messages from СОЛОВЬЁВ
# Fetched 173148 messages...
# Fetching messages from Сталингулаг
# Fetched 6600 messages...
# Fetching messages from Таня Ф.
# Fetched 564 messages...
# Fetching messages from Команда Навального
# Fetched 2818 messages...
# Fetching messages from Тина Канделаки
# Fetched 6460 messages...
# Fetching messages from Илья Варламов
# Fetched 6800 messages...
# Fetching messages from Varlamov News
# Fetched 6838 messages...
# Fetching messages from Вячеслав Володин
# Fetched 666 messages...
# Fetching messages from Настоящий Гладков
# Fetched 3000 messages...
# Fetching messages from Старше Эдды
# Fetched 6796 messages...
# Fetching messages from Киты плывут на вписку с ЛСД
# Fetched 795 messages...
#
# Total time elapsed: 9875.93 seconds
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7259446485191733249, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259446544505940993, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259446545983426561, ignoring (see FAQ for details)
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7259494636556363777, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259494785002758145, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259494785004872705, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259494814880913409, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259495402653853697, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259495465755472897, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259495538554225665, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259495680919318529, ignoring (see FAQ for details)
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server resent the older message 7259558217778270209, ignoring
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7259575313334795265, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259576215311555585, ignoring (see FAQ for details)
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7259632142154656769, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259634847964083201, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259635749916229633, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259639357762877441, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259640259739166721, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259640259739166737, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259640259739166725, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259640259739166729, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259640259739166733, ignoring (see FAQ for details)
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7259873667714041857, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259874569696573441, ignoring (see FAQ for details)
# Server closed the connection: 0 bytes read on a total of 8 expected bytes
# Server closed the connection: 0 bytes read on a total of 8 expected bytes
# Unhandled error while receiving data
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/mtprotosender.py", line 505, in _recv_loop
#     body = await self._connection.recv()
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 301, in recv
#     raise err
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 332, in _recv_loop
#     data = await self._recv()
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 369, in _recv
#     return await self._codec.read_packet(self._reader)
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/tcpfull.py", line 25, in read_packet
#     packet_len_seq = await reader.readexactly(8)  # 4 and 4
#   File "/opt/homebrew/Cellar/python@3.10/3.10.6_2/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/streams.py", line 706, in readexactly
#     raise exceptions.IncompleteReadError(incomplete, n)
# asyncio.exceptions.IncompleteReadError: 0 bytes read on a total of 8 expected bytes
# Server closed the connection: 0 bytes read on a total of 8 expected bytes
# Unhandled error while receiving data
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/mtprotosender.py", line 505, in _recv_loop
#     body = await self._connection.recv()
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 301, in recv
#     raise err
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 332, in _recv_loop
#     data = await self._recv()
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 369, in _recv
#     return await self._codec.read_packet(self._reader)
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/tcpfull.py", line 25, in read_packet
#     packet_len_seq = await reader.readexactly(8)  # 4 and 4
#   File "/opt/homebrew/Cellar/python@3.10/3.10.6_2/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/streams.py", line 706, in readexactly
#     raise exceptions.IncompleteReadError(incomplete, n)
# asyncio.exceptions.IncompleteReadError: 0 bytes read on a total of 8 expected bytes
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7259887553553740801, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259887554181702657, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259888456155225097, ignoring (see FAQ for details)
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7259954626317064193, ignoring (see FAQ for details)
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7259989803532317705, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259990705639090177, ignoring (see FAQ for details)
# Server sent a very old message with ID 7259991607473674249, ignoring (see FAQ for details)
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server resent the older message 7259999180910139393, ignoring
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7260006039569314825, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260006941011708937, ignoring (see FAQ for details)
# Server resent the older message 7260017318771431425, ignoring
# Server closed the connection: 0 bytes read on a total of 8 expected bytes
# Server closed the connection: 0 bytes read on a total of 8 expected bytes
# Unhandled error while receiving data
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/mtprotosender.py", line 505, in _recv_loop
#     body = await self._connection.recv()
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 301, in recv
#     raise err
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 332, in _recv_loop
#     data = await self._recv()
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 369, in _recv
#     return await self._codec.read_packet(self._reader)
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/tcpfull.py", line 25, in read_packet
#     packet_len_seq = await reader.readexactly(8)  # 4 and 4
#   File "/opt/homebrew/Cellar/python@3.10/3.10.6_2/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/streams.py", line 706, in readexactly
#     raise exceptions.IncompleteReadError(incomplete, n)
# asyncio.exceptions.IncompleteReadError: 0 bytes read on a total of 8 expected bytes
# Server closed the connection: 0 bytes read on a total of 8 expected bytes
# Unhandled error while receiving data
# Traceback (most recent call last):
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/mtprotosender.py", line 505, in _recv_loop
#     body = await self._connection.recv()
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 301, in recv
#     raise err
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 332, in _recv_loop
#     data = await self._recv()
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/connection.py", line 369, in _recv
#     return await self._codec.read_packet(self._reader)
#   File "/opt/homebrew/lib/python3.10/site-packages/telethon/network/connection/tcpfull.py", line 25, in read_packet
#     packet_len_seq = await reader.readexactly(8)  # 4 and 4
#   File "/opt/homebrew/Cellar/python@3.10/3.10.6_2/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/streams.py", line 706, in readexactly
#     raise exceptions.IncompleteReadError(incomplete, n)
# asyncio.exceptions.IncompleteReadError: 0 bytes read on a total of 8 expected bytes
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7260045889194036225, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260045892949204993, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260045893490765825, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260045898027612161, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260045900723248129, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260045903708389377, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260045909116156929, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260045914024927233, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260046538133910529, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260046538133910545, ignoring (see FAQ for details)
# Security error while unpacking a received message: Too many messages had to be ignored consecutively
# Server sent a very old message with ID 7260046538133910533, ignoring (see FAQ for details)
# Security error while unpacking a received message: Too many messages had to be ignored consecutively
# Server sent a very old message with ID 7260046628131489793, ignoring (see FAQ for details)
# Security error while unpacking a received message: Too many messages had to be ignored consecutively
# Server sent a very old message with ID 7260047530123804673, ignoring (see FAQ for details)
# Security error while unpacking a received message: Too many messages had to be ignored consecutively
# Server sent a very old message with ID 7260121872952621065, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260121872952621057, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260121872952621061, ignoring (see FAQ for details)
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server sent a very old message with ID 7260127651005198337, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260127720576949249, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260127720576949253, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260127729485071361, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260127808150632449, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260127961328855041, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260128040472116225, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260128043273295873, ignoring (see FAQ for details)
# Server sent a very old message with ID 7260128060427868161, ignoring (see FAQ for details)
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer
# Server closed the connection: [Errno 54] Connection reset by peer

# %%
client.is_connected()
# Out:
# True

# %%
client.disconnect()
# Out:
# <Future pending cb=[shield.<locals>._outer_done_callback() at /opt/homebrew/Cellar/python@3.10/3.10.6_2/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/tasks.py:857]>
